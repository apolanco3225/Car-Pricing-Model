# %%
# import necessary packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %%
crashers_df = pd.read_csv("crashes_poverty.csv", delimiter=";")
crashers_df.head()
# Out:
#         State  Number of Crashes  Poverty
# 0     Florida               1011     13.7
# 1   Tennessee                437     15.2
# 2  New Mexico                344     18.8
# 3     Alabama                336     16.8
# 4   Louisiana                271     18.7

# %%
crashers_df.columns = ["state", "crashes", "poverty"]
crashers_df.head()
# Out:
#         state  crashes  poverty
# 0     Florida     1011     13.7
# 1   Tennessee      437     15.2
# 2  New Mexico      344     18.8
# 3     Alabama      336     16.8
# 4   Louisiana      271     18.7

# %%
crashers_df.dtypes
# Out:
# state       object
# crashes      int64
# poverty    float64
# dtype: object

# %%
crashers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   state    50 non-null     object
#  1   crashes  50 non-null     int64
#  2   poverty  50 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.3+ KB

# %%
location = [i for i in range(len(crashers_df))]
plt.subplots(figsize=(30,30))
plt.rcParams['font.size'] = 40

plt.barh(
    location,
    crashers_df.crashes, 
    tick_label=crashers_df.state,
    
)
plt.ylabel("States",fontsize=40)
plt.xlabel("Number of Crashes", fontsize=40)
plt.title("Number of Crashes Per State", fontsize=40);

# %%
plt.subplots(figsize=(30,30))
plt.rcParams['font.size'] = 40

plt.barh(
    location,
    crashers_df.poverty, 
    tick_label=crashers_df.state,
    
)
plt.ylabel("States")
plt.xlabel("Poverty Indicator")
plt.title("Poverty in the States");

# %%
crashers_df.shape
# Out:
# (50, 3)
